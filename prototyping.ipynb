# %%
from sklearn.tree import DecisionTreeClassifier
from preprocess import X_train, X_test, Y_train, Y_test
from sklearn.metrics import accuracy_score

basicTreeClassifier = DecisionTreeClassifier(
    criterion = "entropy",
    splitter = "best",
    #max_depth = 10,
    min_samples_split = 2,
    random_state=42,
    max_depth=3
)

basicTreeClassifier.fit(X=X_train, y=Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

# %%
y_pred = basicTreeClassifier.predict(X_test)

accuracy = accuracy_score(Y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.645

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(basicTreeClassifier)
# Out:
# [Text(0.5, 0.875, 'x[20] <= 16.079\nentropy = 0.934\nsamples = 400\nvalue = [260, 140]'),
#  Text(0.25, 0.625, 'x[20] <= 8.092\nentropy = 0.898\nsamples = 353\nvalue = [242, 111]'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'x[19] <= 3.72\nentropy = 0.986\nsamples = 58\nvalue = [25, 33]'),
#  Text(0.0625, 0.125, 'entropy = 0.414\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.1875, 0.125, 'entropy = 0.999\nsamples = 46\nvalue = [24, 22]'),
#  Text(0.375, 0.375, 'x[19] <= 14.935\nentropy = 0.833\nsamples = 295\nvalue = [217.0, 78.0]'),
#  Text(0.3125, 0.125, 'entropy = 0.818\nsamples = 291\nvalue = [217, 74]'),
#  Text(0.4375, 0.125, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.75, 0.625, 'x[12] <= 1.0\nentropy = 0.96\nsamples = 47\nvalue = [18, 29]'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'x[7] <= 1.0\nentropy = 0.98\nsamples = 24\nvalue = [14, 10]'),
#  Text(0.5625, 0.125, 'entropy = 0.971\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.6875, 0.125, 'entropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.875, 0.375, 'x[3] <= 1.0\nentropy = 0.667\nsamples = 23\nvalue = [4, 19]'),
#  Text(0.8125, 0.125, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.9375, 0.125, 'entropy = 0.918\nsamples = 12\nvalue = [4, 8]')]

# %%
# from sklearn.tree import export_graphviz
# from six import StringIO 
# from IPython.display import Image  
# import pydotplus

# feature_cols = list(X_train.columns)

# dot_data = StringIO()
# export_graphviz(basicTreeClassifier, out_file=dot_data,  
#                 filled=True, rounded=True,
#                 special_characters=True,feature_names = feature_cols,class_names=['0','1'])
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# graph.write_png('diabetes.png')
# Image(graph.create_png())
