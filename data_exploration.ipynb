# %%
import pandas as pd
import numpy as np
from preprocess import X_train, X_test, Y_train, Y_test
import matplotlib.pyplot as plt

# %%
from preprocess import sampled_predictors,sampled_targets, data_matrix

# %%
import seaborn as sns

# %%
import pandas as pd
data = pd.read_csv("data.csv")
len([stupid for stupid in data["long"] if stupid <0])
# Out:
# 17

# %% [markdown]
# As we can see, there are 17 observations with negative lengths. This seams like invalid data points which is why we will ignore these rows when preprocessing our data.

# %%
sns.histplot(data_matrix["rec"])
# Out:
# <Axes: xlabel='rec', ylabel='Count'>
