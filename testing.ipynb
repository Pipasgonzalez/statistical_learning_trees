# %%
import sklearn
import pandas as pd

# %%
dataset = pd.read_csv("data.csv") 
target = pd.read_csv("flowering_time.csv")

# %%
dataset.describe()
# Out:
#          gtype.14    gtype.15    gtype.18    gtype.26    gtype.43    gtype.50  \
# count  697.000000  697.000000  697.000000  697.000000  697.000000  697.000000
# mean     0.393113    0.791966    0.575323    0.879484    0.443329    0.457676
# std      0.793551    0.969977    0.903613    0.992701    0.823515    0.838205
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    2.000000    2.000000    2.000000    0.000000    0.000000
# max      2.000000    2.000000    2.000000    2.000000    2.000000    2.000000
#
#          gtype.57    gtype.72    gtype.87    gtype.90  ...   gtype.100  \
# count  697.000000  697.000000  697.000000  697.000000  ...  697.000000
# mean     0.507891    0.703013    0.727403    0.579627  ...    0.637016
# ...

# %%
target.describe()
# Out:
#              45.0
# count  696.000000
# mean    38.793103
# std     12.877296
# min     21.000000
# 25%     28.000000
# 50%     34.000000
# 75%     50.500000
# max     74.000000
